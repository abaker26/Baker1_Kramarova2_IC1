# %% [markdown]
# ### In-Class Assignment: Web Scraping and Data Extraction from a New Webpage
# Use the requests library to fetch a new webpage.
# Parse the HTML content using BeautifulSoup.
# Extract various elements such as figures, tables, and text.
# Work collaboratively in groups to practice web scraping and present their findings.
# - Task 1: Select a Webpage of interest (e.g., a news article, an educational resource, or a data-driven website). Ensure that the selected webpage contains a variety of elements, such as tables, figures, and text content.
# - Task 2: Fetch and Parse the Webpage

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://en.wikipedia.org/wiki/List_of_college_athletic_programs_in_Kentucky'
response = requests.get(url)

# %%
# Check if the request was successful
if response.status_code == 200:
    print("Successfully fetched the webpage!")
else:
    print("Failed to fetch the webpage.")
# Out:
# Successfully fetched the webpage!

# %%
# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(response.text, 'html.parser')

# %% [markdown]
# ### Task 3: Extract Elements

# %%
#Find all images and extract their src attributes.
images = soup.find_all('img')
image_urls = [img['src'] for img in images if 'src' in img.attrs]
print(image_urls)
# Out:
# ['/static/images/icons/wikipedia.png', '/static/images/mobile/copyright/wikipedia-wordmark-en.svg', '/static/images/mobile/copyright/wikipedia-tagline-en.svg', '//upload.wikimedia.org/wikipedia/commons/thumb/8/84/USA_Kentucky_location_map.svg/400px-USA_Kentucky_location_map.svg.png', '//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png', '//upload.wikimedia.org/wikipedia/commons/thumb/0/0c/Red_pog.svg/8px-Red_pog.svg.png', '//upload.wikimedia.org/wikipedia/commons/thumb/d/d7/Blue_pog.svg/8px-Blue_pog.svg.png', '//upload.wikimedia.org/wikipedia/commons/thumb/d/d7/Blue_pog.svg/8px-Blue_pog.svg.png', '//upload.wikimedia.org/wikipedia/commons/thumb/0/0c/Red_pog.svg/8px-Red_pog.svg.png', '//upload.wikimedia.org/wikipedia/commons/thumb/0/0c/Red_pog.svg/8px-Red_pog.svg.png', '//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png', '//upload.wikimedia.org/wikipedia/commons/thumb/d/d7/Blue_pog.svg/8px-Blue_pog.svg.png', '//upload.wikimedia.org/wikipedia/commons/thumb/d/d7/Blue_pog.svg/10px-Blue_pog.svg.png', '//upload.wikimedia.org/wikipedia/commons/thumb/0/0c/Red_pog.svg/10px-Red_pog.svg.png', '//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png', '//upload.wikimedia.org/wikipedia/commons/thumb/9/9d/Yellow_pog.svg/10px-Yellow_pog.svg.png', '//upload.wikimedia.org/wikipedia/commons/thumb/a/a2/Brown_check.svg/13px-Brown_check.svg.png', '//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png', '//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png', '//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png', '//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png', '//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png', '//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png', '//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png', '//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png', '//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png', '//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png', '//upload.wikimedia.org/wikipedia/commons/thumb/4/48/Dark_Red_x.svg/13px-Dark_Red_x.svg.png', '//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png', '//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png', '//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png', '//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png', '//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png', '//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png', '//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png', '//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png', '//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png', '//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png', '//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png', '//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png', '//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png', '//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png', '//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png', '//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png', '//upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png', '//upload.wikimedia.org/wikipedia/commons/thumb/4/48/Dark_Red_x.svg/13px-Dark_Red_x.svg.png', '//uploa ...

# %%
import requests
from bs4 import BeautifulSoup

url = "https://en.wikipedia.org/wiki/List_of_college_athletic_programs_in_Kentucky"
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

images = soup.find_all('img')
for img in images:
    img_url = img.get('src')
    print(img_url)
# Out:
# /static/images/icons/wikipedia.png
# /static/images/mobile/copyright/wikipedia-wordmark-en.svg
# /static/images/mobile/copyright/wikipedia-tagline-en.svg
# //upload.wikimedia.org/wikipedia/commons/thumb/8/84/USA_Kentucky_location_map.svg/400px-USA_Kentucky_location_map.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/0/0c/Red_pog.svg/8px-Red_pog.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/d/d7/Blue_pog.svg/8px-Blue_pog.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/d/d7/Blue_pog.svg/8px-Blue_pog.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/0/0c/Red_pog.svg/8px-Red_pog.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/0/0c/Red_pog.svg/8px-Red_pog.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/d/d7/Blue_pog.svg/8px-Blue_pog.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/d/d7/Blue_pog.svg/10px-Blue_pog.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/0/0c/Red_pog.svg/10px-Red_pog.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/9/9d/Yellow_pog.svg/10px-Yellow_pog.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/a/a2/Brown_check.svg/13px-Brown_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/4/48/Dark_Red_x.svg/13px-Dark_Red_x.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/4/48/Dark_Red_x.svg/13px-Dark_Red_x.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/4/48/Dark_Red_x.svg/13px-Dark_Red_x.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/4/48/Dark_Red_x.svg/13px-Dark_Red_x.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/4/48/Dark_Red_x.svg/13px-Dark_Red_x.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/8/84/USA_Kentucky_location_map.svg/350px-USA_Kentucky_location_map.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/d/d7/Blue_pog.svg/8px-Blue_pog.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/d/d7/Blue_pog.svg/8px-Blue_pog.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/d/d7/Blue_pog.svg/8px-Blue_pog.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/4/48/Dark_Red_x.svg/13px-Dark_Red_x.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/4/48/Dark_Red_x.svg/13px-Dark_Red_x.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/8/84/USA_Kentucky_location_map.svg/400px-USA_Kentucky_location_map.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/d/d7/Blue_pog.svg/8px-Blue_pog.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/d/d7/Blue_pog.svg/10px-Blue_pog.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/4/48/Dark_Red_x.svg/13px-Dark_Red_x.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/4/48/Dark_Red_x.svg/13px-Dark_Red_x.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/4/48/Dark_Red_x.svg/13px-Dark_Red_x.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/4/48/Dark_Red_x.svg/13px-Dark_Red_x.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/8/84/USA_Kentucky_location_map.svg/400px-USA_Kentucky_location_map.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/d/d7/Blue_pog.svg/8px-Blue_pog.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/d/d7/Blue_pog.svg/8px-Blue_pog.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/d/d7/Blue_pog.svg/8px-Blue_pog.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/d/d7/Blue_pog.svg/8px-Blue_pog.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/d/d7/Blue_pog.svg/8px-Blue_pog.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/9/9d/Yellow_pog.svg/8px-Yellow_pog.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/d/d7/Blue_pog.svg/8px-Blue_pog.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/d/d7/Blue_pog.svg/8px-Blue_pog.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/d/d7/Blue_pog.svg/10px-Blue_pog.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/9/9d/Yellow_pog.svg/10px-Yellow_pog.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/4/48/Dark_Red_x.svg/13px-Dark_Red_x.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/4/48/Dark_Red_x.svg/13px-Dark_Red_x.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/4/48/Dark_Red_x.svg/13px-Dark_Red_x.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/4/48/Dark_Red_x.svg/13px-Dark_Red_x.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/a/a2/Brown_check.svg/13px-Brown_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/f/fb/Yes_check.svg/13px-Yes_check.svg.png
# https://login.wikimedia.org/wiki/Special:CentralAutoLogin/start?type=1x1
# /static/images/footer/wikimedia-button.svg
# /static/images/footer/poweredby_mediawiki.svg

# %%
# Run to see image

import requests
from PIL import Image
from io import BytesIO

# Corrected URL of the image
img_url = "https://upload.wikimedia.org/wikipedia/commons/thumb/8/84/USA_Kentucky_location_map.svg/400px-USA_Kentucky_location_map.svg.png"

# Fetch the image
response = requests.get(img_url)

# Check if the content type is an image
if 'image' in response.headers['Content-Type']:
    img = Image.open(BytesIO(response.content))
    # Display the image
    img.show()
else:
    print("The URL does not point to an image.")

# %%
# Locate and extract all tables on the webpage, converting them into Pandas DataFrames.
import pandas as pd

tables = soup.find_all('table')
for i, table in enumerate(tables):
    df = pd.read_html(str(table))[0]
    print(f"Table {i+1}:\n", df.head(), "\n")
# Out:
# Table 1:
#                          Team                       School        City  \
#                         Team                       School        City
#                         Team                       School        City
# 0         Bellarmine Knights        Bellarmine University  Louisville
# 1  Eastern Kentucky Colonels  Eastern Kentucky University    Richmond
# 2          Kentucky Wildcats       University of Kentucky   Lexington
# 3       Louisville Cardinals     University of Louisville  Louisville
# 4      Morehead State Eagles    Morehead State University    Morehead
#
#   Conference Sport sponsorship
#   Conference        Foot- ball Basketball     Base- ball Soft- ball Soccer
#   Conference        Foot- ball          M   W Base- ball Soft- ball      M   W
# 0       ASUN               [a]        NaN NaN        NaN        NaN    NaN NaN
# 1       ASUN           FCS [b]        NaN NaN        NaN        NaN    NaN NaN
# 2        SEC               FBS        NaN NaN        NaN        NaN    [c] NaN
# 3        ACC               FBS        NaN NaN        NaN        NaN    NaN NaN
# 4        OVC           FCS [d]        NaN NaN        NaN        NaN    NaN NaN
#
# Table 2:
#                                           Team                     School  \
#                                          Team                     School
#                                          Team                     School
# 0  Kentucky State Thorobreds and Thorobrettes  Kentucky State University
# 1                  Kentucky Wesleyan Panthers  Kentucky Wesleyan College
# 2                      Thomas More Saints [a]     Thomas More University
#
#               City Conference Sport sponsorship                            \
#               City Conference        Foot- ball Basketball     Base- ball
#               City Conference        Foot- ball          M   W Base- ball
# 0        Frankfort       SIAC               NaN        NaN NaN        NaN
# 1        Owensboro      G-MAC               NaN        NaN NaN        NaN
# 2  Crestview Hills      G-MAC               NaN        NaN NaN        NaN
#
#
#   Soft- ball Soccer
#   Soft- ball      M   W
# 0        NaN    NaN NaN
# 1        NaN    NaN NaN
# 2        NaN    NaN NaN
#
# Table 3:
#                       Team                   School        City Conference  \
#                      Team                   School        City Conference
#                      Team                   School        City Conference
# 0           Asbury Eagles        Asbury University     Wilmore        CCS
# 1      Berea Mountaineers            Berea College       Berea       HCAC
# 2         Centre Colonels           Centre College    Danville        SAA
# 3  Spalding Golden Eagles      Spalding University  Louisville      SLIAC
# 4   Transylvania Pioneers  Transylvania University   Lexington       HCAC
#
#   Sport sponsorship
#          Foot- ball Basketball     Base- ball Soft- ball Soccer
#          Foot- ball          M   W Base- ball Soft- ball      M   W
# 0               NaN        NaN NaN        NaN        NaN    NaN NaN
# 1               NaN        NaN NaN        NaN        NaN    NaN NaN
# 2               NaN        NaN NaN        NaN        NaN    NaN NaN
# 3               NaN        NaN NaN        NaN        NaN    NaN NaN
# 4               NaN        NaN NaN        NaN        NaN    NaN NaN
#
# Table 4:
#                      Team                         School            City  \
#                     Team                         School            City
#                     Team                         School            City
# 0     Alice Lloyd Eagles            Alice Lloyd College    Pippa Passes
# 1       Brescia Bearcats             Brescia University       Owensboro
# 2  Campbellsville Tigers      Campbellsville University  Campbellsville
# 3   Cumberlands Patriots  University of the Cumberlands    Williamsburg
# 4      Georgetown Tigers             Georgetown College      Georgetown
#
#      Conference Sport sponsorship                                              \
#      Conference        Foot- ball Basketball     Base- ball Soft- ball Soccer
#      Conference        Foot- ball          M   W Base- ball Soft- ball      M
# 0  River States               NaN        NaN NaN        NaN        NaN    NaN
# 1  River States               NaN        NaN NaN        NaN        NaN    NaN
# 2     Mid-South               [a]        NaN NaN        NaN        NaN    NaN
# 3     Mid-South               NaN        NaN NaN        NaN        NaN    NaN
# 4     Mid-South               NaN        NaN NaN        NaN        NaN    NaN
#
#
#
#     W
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN
#
# Table 5:
#                        Team                       School            City  \
# 0           Boyce Bulldogs                Boyce College      Louisville
# 1  Campbellsville Pioneers    Campbellsville University  Campbellsville
# 2  Simmons College Falcons  Simmons College of Kentucky      Louisville
#
#   Conference
# 0   Mid-East
# 1   Mid-East
# 2   Mid-East
#
# Table 6:
#    .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar a>span,.mw-parser-output .navbar a>abbr{text-decoration:inherit}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}html.skin-theme-clientpref-night .mw-parser-output .navbar li a abbr{color:var(--color-base)!important}@media(prefers-color-scheme:dark){html.skin-theme-clientpref-os .mw-parser-output .navbar li a abbr{color:var(--color-base)!important}}@media print{.mw-parser-output .navbar{display:none!important}}vteCollege athletic programs in the United States by state or territory  \
# 0  Alabama Alaska Arizona Arkansas California Col...
#
#   .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar a>span,.mw-parser-output .navbar a>abbr{text-decoration:inherit}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}html.skin-theme-clientpref-night .mw-parser-output .navbar li a abbr{color:var(--color-base)!important}@media(prefers-color-scheme:dark){html.skin-theme-clientpref-os .mw-parser-output .navbar li a abbr{color:var(--color-base)!important}}@media print{.mw-parser-output .navbar{display:none!important}}vteCollege athletic programs in the United States by state or territory.1
# 0  Alabama Alaska Arizona Arkansas California Col...

# %%
table=tables[0] if tables else None
if table:
    print("Table found")
else:
    print("No table found")
# Out:
# Table found

# %%
df=pd.read_html(str(table))[0]
df.head()
# Out:
#                         Team                       School        City  \
#                         Team                       School        City
#                         Team                       School        City
# 0         Bellarmine Knights        Bellarmine University  Louisville
# 1  Eastern Kentucky Colonels  Eastern Kentucky University    Richmond
# 2          Kentucky Wildcats       University of Kentucky   Lexington
# 3       Louisville Cardinals     University of Louisville  Louisville
# 4      Morehead State Eagles    Morehead State University    Morehead
#
#   Conference Sport sponsorship
#   Conference        Foot- ball Basketball     Base- ball Soft- ball Soccer
#   Conference        Foot- ball          M   W Base- ball Soft- ball      M   W
# 0       ASUN               [a]        NaN NaN        NaN        NaN    NaN NaN
# 1       ASUN           FCS [b]        NaN NaN        NaN        NaN    NaN NaN
# 2        SEC               FBS        NaN NaN        NaN        NaN    [c] NaN
# 3        ACC               FBS        NaN NaN        NaN        NaN    NaN NaN
# 4        OVC           FCS [d]        NaN NaN        NaN        NaN    NaN NaN

# %%
#Extract the main text content, such as paragraphs or headings.
paragraphs = soup.find_all('p')
text_content = ' '.join([para.get_text() for para in paragraphs])
print(text_content[:500])  # Print the first 500 characters
# Out:
# This is a list of college athletics programs in the U.S. state of Kentucky.

# %% [markdown]
# ### Task 4: Analyze and Discuss Findings
# Each group will analyze the extracted data and discuss the following:
# - What figures (images) were extracted and what do they represent?
# - What information is contained in the tables, and how does it contribute to the overall content of the webpage?
# - What is the main focus of the text content extracted? How does it relate to the images and tables?
# - Discuss the challenges faced during extraction, such as dealing with complex HTML structures or incomplete data.

# %% [markdown]
# ### Task 5: Present Findings
# Shares your analysis of the extracted elements.
# Discusses any patterns, relationships, or insights gained from the data.

# %% [markdown]
# Each group should submit their Jupyter notebook (or Python script) with the code, analysis, and any additional notes or reflections on the exercise.

# %% [markdown]
# The image extracted is an image of the state of Kentucky.
# The table contains a list of D1 schools in the state of Kentucky and the characteristics. The table is further discussed throughout the webpage.
# The main focus is the list of D1 schools, city, and conference. The image relates because it is a map of the state of Kentucky.
# A challenge we faced was that we could not extract the exact image from Wikipedia becuase it has so many layers and links.
